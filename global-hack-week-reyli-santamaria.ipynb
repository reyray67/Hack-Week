# %% [markdown]
# <a href="https://www.kaggle.com/code/reylisantamaria/global-hack-week-reyli-santamaria?scriptVersionId=158491678" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Hello, World!

# %%
print("Hello World")

# %% [markdown]
# # Write A Sorting Method

# %%
My_Favorite_Things = ['GF', 'Food', 'Video Games', 'Music']
My_Favorite_Things.sort()
My_Favorite_Things
# Out:
# ['Food', 'GF', 'Music', 'Video Games']

# %% [markdown]
# # Rock, Paper, Scissors Game

# %%
import random 

player = input( "Enter a choice (rock, paper, scissors):")
options = ["rock","paper", "scissors"]
computer_action= random.choice(options)
print(f"\nYou chose {player}, computer chose {computer_action}.\n")

if player == computer_action:
    print(f"Both players selected {player}. It's a tie!")
elif player == "rock":
    if computer_action == "scissors":
        print("Rock beats scissors! You win!")
    else:
        print("Paper covers rock! YOU LOSE.")
elif player == "paper":
    if computer_action == "rock":
        print("Paper covers rock! You win!")
    else:
        print("Scissors cuts paper! YOU LOSE.")
elif player == "scissors":
    if computer_action == "paper":
        print("Scissors cuts paper! You win!")
    else:
        print("Rock beats scissors! YOU LOSE.")
# Out:
# Enter a choice (rock, paper, scissors): paper
# You chose paper, computer chose rock.
#
# Paper covers rock! You win!

# %% [markdown]
# #  Build a random number generator

# %%
import random 

num= random.random() 
print(num) #prints a random floating point b/w 1 and 0
# Out:
# 0.5294937417105082

# %% [markdown]
# **another way to do it**

# %%
import random 
number= random.randint(1,1000) #choses a random number b/w 1 to 1000

print(number)
# Out:
# 557

# %% [markdown]
# #  Create A Project to Achieve Your New Year's Resolution

# %%
tasks = []

def addTask():
  task = input("Please enter a task: ")
  tasks.append(task)
  print(f"Task '{task}' added successfully.")


def show_list():
  if not tasks:
    print("There are no tasks currently.")
  else:
    print("Current Tasks:")
    for index, task in enumerate(tasks, start=1):
      print(f"Task #{index}. {task}")


def removeTask():
  show_list()
  try:
    Tasktoremove = int(input("Enter the # to delete: "))
    if Tasktoremove >= 0 and Tasktoremove < len(tasks):
      tasks.pop(Tasktoremove)
      print(f"Task {Tasktoremove} has been removed.")
    else:
      print(f"Task #{Tasktoremove} was not found.")
  except:
    print("Invalid input.")


if __name__ == "__main__":
  
  print("TO DO LIST")
  while True:
    print("\n Select one of the following options")
    print("------------------------------------------")
    print("1. Add a new task")
    print("2. Remove a task")
    print("3. Show the list")
    print("4. Leave")

    choice = input("Enter your choice: ")

    if (choice == "1"):
      addTask()
    elif (choice == "2"):
      removeTask()
    elif (choice == "3"):
      show_list()
    elif (choice == "4"):
      break
    else:
      print("It's only from 1 to 4! Please try again.")

  print("REMEMBER YOUR TASKS!!")
# Out:
# TO DO LIST
#
#  Select one of the following options
# ------------------------------------------
# 1. Add a new task
# 2. Remove a task
# 3. Show the list
# 4. Leave
# Enter your choice:  1

# %% [markdown]
# # Create a Useless Hack

# %%
import random 

def question(): 
    player = input( "Enter a choice (yes/no):").lower()

if player == "yes":
    player = input("")

question()
# Out:
# You chose yes, computer chose yes.
# Enter a choice (yes/no): yes

# %% [markdown]
# #  Hack with ChatGPT

# %%
import random

def guess_the_number():
    secret_number = random.randint(1, 100)
    
    print("Welcome to the Number Guessing Game!")
    print("I've chosen a number between 1 and 100. Try to guess it!")

    attempts = 0

    while True:
        user_guess = int(input("Your guess: "))
        attempts += 1

        if user_guess == secret_number:
            print(f"Congratulations! You guessed the number in {attempts} attempts.")
            break
        elif user_guess < secret_number:
            print("Too low. Try again!")
        else:
            print("Too high. Try again!")
            
guess_the_number()
